# %%
import numpy as np
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Regression Analysis: Seasonal Effects with Sklearn Linear Regression
# In this notebook, you will build a SKLearn linear regression model to predict Yen futures ("settle") returns with *lagged* Yen futures returns.

# %%
# Futures contract on the Yen-dollar exchange rate:
# This is the continuous chain of the futures contracts that are 1 month to expiration
yen_futures = pd.read_csv(
    Path("yen.csv"), index_col="Date", infer_datetime_format=True, parse_dates=True
)
yen_futures.head()
# Out:
#               Open    High     Low    Last  Change  Settle  Volume  \
# Date
# 1976-08-02  3398.0  3401.0  3398.0  3401.0     NaN  3401.0     2.0
# 1976-08-03  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-04  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-05  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-06  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
#
#             Previous Day Open Interest
# Date
# 1976-08-02                         1.0
# 1976-08-03                         1.0
# 1976-08-04                         1.0
# 1976-08-05                         1.0
# 1976-08-06                         1.0

# %%
# Trim the dataset to begin on January 1st, 1990
yen_futures = yen_futures.loc["1990-01-01":, :]
yen_futures.head()
# Out:
#               Open    High     Low    Last  Change  Settle   Volume  \
# Date
# 1990-01-02  6954.0  6954.0  6835.0  6847.0     NaN  6847.0  48336.0
# 1990-01-03  6877.0  6910.0  6865.0  6887.0     NaN  6887.0  38206.0
# 1990-01-04  6937.0  7030.0  6924.0  7008.0     NaN  7008.0  49649.0
# 1990-01-05  6952.0  6985.0  6942.0  6950.0     NaN  6950.0  29944.0
# 1990-01-08  6936.0  6972.0  6936.0  6959.0     NaN  6959.0  19763.0
#
#             Previous Day Open Interest
# Date
# 1990-01-02                     51473.0
# 1990-01-03                     53860.0
# 1990-01-04                     55699.0
# 1990-01-05                     53111.0
# 1990-01-08                     52072.0

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Returns

# %%
# Create a series using "Settle" price percentage returns, drop any nan"s, and check the results:
# (Make sure to multiply the pct_change() results by 100)
# In this case, you may have to replace inf, -inf values with np.nan"s
yen_futures['Returns'] = yen_futures['Settle'].pct_change()*100
yen_futures.dropna(inplace=True)
yen_futures
# Out:
#               Open    High     Low    Last  Change  Settle    Volume  \
# Date
# 2014-02-18  9831.0  9865.0  9734.0  9775.0    42.0  9775.0  203495.0
# 2014-02-19  9768.0  9825.0  9760.0  9773.0     2.0  9773.0  129508.0
# 2014-02-20  9774.0  9837.0  9765.0  9775.0     2.0  9775.0  160202.0
# 2014-02-21  9772.0  9776.0  9725.0  9758.0    20.0  9755.0  103091.0
# 2014-02-24  9752.0  9789.0  9740.0  9757.0     2.0  9757.0   90654.0
# 2014-02-25  9760.0  9808.0  9744.0  9789.0    32.0  9789.0  105498.0
# 2014-02-26  9784.0  9795.0  9746.0  9760.0    29.0  9760.0  118559.0
# 2014-02-27  9769.0  9831.0  9762.0  9798.0    38.0  9798.0  160638.0
# 2014-02-28  9787.0  9848.0  9776.0  9825.0    27.0  9825.0  169374.0
# 2014-03-03  9840.0  9882.0  9840.0  9857.0    34.0  9859.0  149003.0
# 2014-03-04  9859.0  9862.0  9776.0  9785.0    79.0  9780.0  137014.0
# 2014-03-06  9771.0  9773.0  9692.0  9705.0    69.0  9705.0  172188.0
# ...

# %% [markdown]
# ### Lagged Returns

# %%
# Create a lagged return using the shift function
yen_futures['Lagged_Returns'] = yen_futures['Returns'].shift().dropna()
yen_futures.tail()
# Out:
#               Open    High     Low    Last  Change  Settle    Volume  \
# Date
# 2019-10-09  9381.0  9391.5  9330.5  9343.5    38.5  9338.0   99153.0
# 2019-10-10  9343.5  9380.5  9293.5  9301.0    34.5  9303.5  159397.0
# 2019-10-11  9308.5  9309.0  9240.0  9267.0    52.5  9251.0  158810.0
# 2019-10-14  9259.0  9292.0  9250.5  9261.0    14.0  9265.0   69457.0
# 2019-10-15  9264.5  9280.0  9216.5  9220.0    43.5  9221.5  108342.0
#
#             Previous Day Open Interest   Returns  Lagged_Returns
# Date
# 2019-10-09                    145470.0 -0.410601        0.170931
# 2019-10-10                    144474.0 -0.369458       -0.410601
# 2019-10-11                    147471.0 -0.564304       -0.369458
# 2019-10-14                    153902.0  0.151335       -0.564304
# 2019-10-15                    151564.0 -0.469509        0.151335

# %% [markdown]
# ### Train Test Split

# %%
# Create a train/test split for the data using 2018-2019 for testing and the rest for training
train = yen_futures[:'2018'].dropna()
test = yen_futures['2018':]

# %%
# Create four dataframes:
# X_train (training set using just the independent variables), X_test (test set of of just the independent variables)
# Y_train (training set using just the "y" variable, i.e., "Futures Return"), Y_test (test set of just the "y" variable):
X_train = train['Lagged_Returns'].dropna()
Y_train = train['Returns'].dropna()

X_test = test['Lagged_Returns'].dropna()
Y_test = test['Returns'].dropna()

# %%
X_train.to_frame()
# Out:
#             Lagged_Returns
# Date
# 2014-02-19       -0.427829
# 2014-02-20       -0.020460
# 2014-02-21        0.020465
# 2014-02-24       -0.204604
# 2014-02-25        0.020502
# 2014-02-26        0.327970
# 2014-02-27       -0.296251
# 2014-02-28        0.389344
# 2014-03-03        0.275566
# 2014-03-04        0.346056
# 2014-03-06       -0.801298
# 2014-03-07       -0.766871
# 2014-03-10       -0.247295
# 2014-03-11        0.103295
# 2014-03-12        0.278609
# 2014-03-13        0.216094
# 2014-03-14        1.026799
# 2014-03-17        0.365891
# 2014-03-18       -0.405063
# 2014-03-19        0.203355
# 2014-03-20       -0.953831
# 2014-03-21        0.030735
# 2014-03-24        0.235559
# 2014-03-25       -0.020435
# 2014-03-26       -0.020439
# 2014-03-27        0.194214
# 2014-03-28       -0.112222
# 2014-03-31       -0.612808
# 2014-04-01       -0.400781
# 2014-04-02       -0.474618
# ...                    ...
# 2018-11-16       -0.113218
# 2018-11-19        0.663077
# ...

# %%
#reshaping the data to (-1,1) array to be in the correct format for Linear Regression model

X_train = X_train.values.reshape(-1,1)
X_test  =X_test.values.reshape(-1,1)
X_train
# Out:
# array([[-0.42782928],
#        [-0.02046036],
#        [ 0.02046455],
#        ...,
#        [-0.89334649],
#        [ 0.46452469],
#        [ 0.29724225]])

# %% [markdown]
# # Linear Regression Model

# %%
# Create a Linear Regression model and fit it to the training data
from sklearn.linear_model import LinearRegression

# Fit a SKLearn linear regression using just the training set (X_train, Y_train):
model = LinearRegression()

model.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# # Make predictions using the Testing Data
#
# Note: We want to evaluate the model using data that it has never seen before, in this case: X_test.

# %%
# Make a prediction of "y" values using just the test dataset

Y_test = Y_test.to_frame()
Y_test['Predicted_Returns'] = model.predict(X_test)

# %%
# Assemble actual y data (Y_test) with predicted y data (from just above) into two columns in a dataframe:

Y_test
# Out:
#              Returns  Predicted_Returns
# Date
# 2018-01-02  0.297285          -0.005887
# 2018-01-03 -0.240479          -0.006597
# 2018-01-04 -0.213028          -0.001325
# 2018-01-05 -0.353933          -0.001594
# 2018-01-08  0.062017          -0.000213
# 2018-01-09  0.388776          -0.004291
# 2018-01-10  1.161812          -0.007494
# 2018-01-11  0.233023          -0.015073
# 2018-01-12  0.016606          -0.005967
# 2018-01-16  0.675190          -0.003846
# 2018-01-17 -0.731131          -0.010302
# 2018-01-18  0.088603           0.003485
# 2018-01-19  0.354100          -0.004551
# 2018-01-22 -0.363877          -0.007154
# 2018-01-23  0.603143          -0.000115
# 2018-01-24  1.160552          -0.009596
# 2018-01-25 -0.347977          -0.015061
# 2018-01-26  0.682017          -0.000271
# 2018-01-29 -0.249282          -0.010369
# 2018-01-30  0.152116          -0.001239
# 2018-01-31 -0.309194          -0.005174
# 2018-02-01 -0.293830          -0.000651
# ...

# %%
# Plot the first 20 predictions vs the true values
Y_test[:20].plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f8bf057aad0>,
# ...
#       dtype=object)

# %%
Y_test[:20].plot(subplots = False)

# %% [markdown]
# # Out-of-Sample Performance
#
# Evaluate the model using "out-of-sample" data (X_test and y_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score
# Calculate the mean_squared_error (MSE) on actual versus predicted test "y"

mse = mean_squared_error(Y_test ['Returns'], Y_test['Predicted_Returns'] )
print(f'Out of Sample Mean squared error (MSE) on actual versus predicted test "y" is {mse}')

# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):

rmse = np.sqrt(mse)

print(f'Root mean squared error (RMSE) on actual versus predicted test "y" is {rmse}')
# Out:
# Out of Sample Mean squared error (MSE) on actual versus predicted test "y" is 0.1724049501748365
# Root mean squared error (RMSE) on actual versus predicted test "y" is 0.41521675083603804

# %% [markdown]
# # In-Sample Performance
#
# Evaluate the model using in-sample data (X_train and y_train)

# %%
# Construct a dataframe using just the "y" training data:
Y_train = Y_train.to_frame()

# Add a column of "in-sample" predictions to that dataframe:  
Y_train['In_sample_Pretictions'] = model.predict(X_train)

# %%
Y_train
# Out:
#              Returns  In_sample_Pretictions
# Date
# 2014-02-19 -0.020460               0.000512
# 2014-02-20  0.020465              -0.003482
# 2014-02-21 -0.204604              -0.003883
# 2014-02-24  0.020502              -0.001677
# 2014-02-25  0.327970              -0.003884
# 2014-02-26 -0.296251              -0.006898
# 2014-02-27  0.389344              -0.000778
# 2014-02-28  0.275566              -0.007500
# 2014-03-03  0.346056              -0.006384
# 2014-03-04 -0.801298              -0.007075
# 2014-03-06 -0.766871               0.004173
# 2014-03-07 -0.247295               0.003836
# 2014-03-10  0.103295              -0.001258
# 2014-03-11  0.278609              -0.004695
# 2014-03-12  0.216094              -0.006414
# 2014-03-13  1.026799              -0.005801
# 2014-03-14  0.365891              -0.013749
# 2014-03-17 -0.405063              -0.007270
# 2014-03-18  0.203355               0.000288
# 2014-03-19 -0.953831              -0.005676
# ...

# %%
# Calculate in-sample mean_squared_error (for comparison to out-of-sample)
mse_in_sample = mean_squared_error(Y_train['Returns'], Y_train['In_sample_Pretictions'] )

print(f'In Sample Mean squared error (MSE) on actual versus predicted test "y" is {mse_in_sample}')

# Calculate in-sample root mean_squared_error (for comparison to out-of-sample)
rmse_in_sample = np.sqrt(mse_in_sample)

print(f'In Sample Root mean squared error (RMSE) on actual versus predicted test "y" is {rmse_in_sample}')
# Out:
# In Sample Mean squared error (MSE) on actual versus predicted test "y" is 0.320209767675256
# In Sample Root mean squared error (RMSE) on actual versus predicted test "y" is 0.5658708047560468

# %%
r2 = r2_score(Y_test ['Returns'], Y_test['Predicted_Returns'])

print(f'R Squared is {r2}')
# Out:
# R Squared is 0.00014859523849397593

# %%
yen_futures[['Lagged_Returns', 'Returns']].corr()
# Out:
#                 Lagged_Returns   Returns
# Lagged_Returns        1.000000 -0.013148
# Returns              -0.013148  1.000000

# %% [markdown]
# # Conclusions

# %% [markdown]
# YOUR CONCLUSIONS HERE!

# %% [markdown]
# Linear Regression model is not a good fit for forecasting Yen pricing based on past performance.
